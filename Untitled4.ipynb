# %%
import pandas as pd
import numpy as np 
df = pd.read_csv("Employee_Sample_Data_Cleaned.csv")
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55    4/8/2016     $141,604
# ...

# %%
new_df = df.replace(["n.a."],np.NaN)
new_df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55    4/8/2016     $141,604
# ...

# %%
group_df = new_df.groupby('Country')
group_df

# %%
for city ,city_df in group_df:
    print(city)
    print(city_df)
# Out:
# Brazil
#        EEID        Full Name             Job Title       Department  \
# 20   E03680   Elias Alvarado            Sr. Manger               IT
# 22   E03484     Logan Rivera              Director               IT
# 26   E04545    Abigail Mejia      Quality Engineer      Engineering
# 31   E00402   Dominic Guzman               Analyst          Finance
# 39   E01417        Leah Pena  Enterprise Architect               IT
# ..      ...              ...                   ...              ...
# 950  E02888     Elijah Ramos            Sr. Manger               IT
# 955  E02561  Samantha Vargas              Director  Human Resources
# 968  E02221   Julian Delgado       Systems Analyst               IT
# 970  E02627     Parker Avila            Analyst II        Marketing
# 991  E03430      Leo Herrera  Sr. Business Partner  Human Resources
#
#               Business Unit  Gender Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
group_df.max('Age')
# Out:
#                Age
# Country
# Brazil          65
# China           65
# United States   65

# %%
group_df.mean('	Age')
# Out:
#                      Age
# Country
# Brazil         43.654676
# China          45.389908
# United States  44.174455

# %%
# %matplotlib inline 
group_df.plot()
# Out:
# Country
# Brazil           Axes(0.125,0.11;0.775x0.77)
# China            Axes(0.125,0.11;0.775x0.77)
# United States    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
Finland_weather = pd.DataFrame({
    "city" : ["Helsinki","Rouma","Poori"],
    "temperature" : [18,24,14],
    "humidity" : [56,45,33]
})
Finland_weather
# Out:
#        city  temperature  humidity
# 0  Helsinki           18        56
# 1     Rouma           24        45
# 2     Poori           14        33

# %%
Nepal_weather  = pd.DataFrame({
    "city" : ["Kathmandu","Tansen","Butwal"],
    "temperature" : [26,23,30],
    "humidity" : [54,45,40]
})
Nepal_weather
# Out:
#         city  temperature  humidity
# 0  Kathmandu           26        54
# 1     Tansen           23        45
# 2     Butwal           30        40

# %%
df_1 = pd.concat([Finland_weather,Nepal_weather],ignore_index = True)
df_1
# Out:
#         city  temperature  humidity
# 0   Helsinki           18        56
# 1      Rouma           24        45
# 2      Poori           14        33
# 3  Kathmandu           26        54
# 4     Tansen           23        45
# 5     Butwal           30        40

# %%
df_2 = pd.concat([Finland_weather,Nepal_weather],keys = ['Finland','Nepal'])
df_2
# Out:
#                 city  temperature  humidity
# Finland 0   Helsinki           18        56
#         1      Rouma           24        45
#         2      Poori           14        33
# Nepal   0  Kathmandu           26        54
#         1     Tansen           23        45
#         2     Butwal           30        40

# %%
df_2.loc['Finland']
# Out:
#        city  temperature  humidity
# 0  Helsinki           18        56
# 1     Rouma           24        45
# 2     Poori           14        33

# %%
df_2.loc['Nepal']
# Out:
#         city  temperature  humidity
# 0  Kathmandu           26        54
# 1     Tansen           23        45
# 2     Butwal           30        40

# %%
temperature_df = pd.DataFrame({
    "city" : ["Rouma","Poori","Helsinki"],
    "temperature" : [26,23,30]
})
temperature_df
# Out:
#        city  temperature
# 0     Rouma           26
# 1     Poori           23
# 2  Helsinki           30

# %%
humidity_df = pd.DataFrame({
    "city" : ["Helsinki","Rouma","Poori"],
    "humidity" : [56,45,33]
})
humidity_df
# Out:
#        city  humidity
# 0  Helsinki        56
# 1     Rouma        45
# 2     Poori        33

# %%
df_3 = pd.concat([temperature_df,humidity_df], axis = 1)
df_3
# Out:
#        city  temperature      city  humidity
# 0     Rouma           26  Helsinki        56
# 1     Poori           23     Rouma        45
# 2  Helsinki           30     Poori        33

# %%
temperature_df.set_index('city', inplace=True)
humidity_df.set_index('city', inplace=True)

# Concatenate the DataFrames along the columns axis
df_4 = pd.concat([temperature_df, humidity_df], axis=1)

# Reset the index if you want 'city' as a column again
df_4.reset_index(inplace=True)

print(df_4)
# Out:
#        city  temperature  humidity
# 0     Rouma           26        45
# 1     Poori           23        33
# 2  Helsinki           30        56

# %%
df_5 = pd.Series(["Humid","Dry","Rain"],name = "event")
df_5
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df_6 =pd.concat([df_4,df_5],axis = 1)
df_6
# Out:
#        city  temperature  humidity  event
# 0     Rouma           26        45  Humid
# 1     Poori           23        33    Dry
# 2  Helsinki           30        56   Rain
