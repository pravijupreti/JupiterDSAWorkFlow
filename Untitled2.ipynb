# %%
import pandas as pd
df = pd.read_csv("customers-100.csv", na_values = {
    'Phone 1' :["not available","n.a."],
    'Phone 2' : ["not available","n.a."]
     })
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df_1 = pd.read_excel("exampleData.xlsx")
df_1
# Out:
#       0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0     1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1     2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3     4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4     5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# ..  ...        ...         ...     ...            ...  ...         ...   ...
# 95   96       Roma  Lafollette  Female  United States   34  15/10/2017  2654
# 96   97     Felisa        Cail  Female  United States   28  16/08/2016  6525
# 97   98   Demetria       Abbey  Female  United States   32  21/05/2015  3265
# 98   99     Jeromy        Danz    Male  United States   39  15/10/2017  3265
# 99  100   Rasheeda      Alkire  Female  United States   29  16/08/2016  6125
#
# [100 rows x 8 columns]

# %%
newValue = df.head(5)
newValue
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
newValue_1 = df_1.head(5)
newValue_1
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
df_1.columns
# Out:
# Index([0, 'First Name', 'Last Name', 'Gender', 'Country', 'Age', 'Date', 'Id'], dtype='object')

# %%
df_1.to_csv('ConvertedUsingPandas.csv',columns = ['First Name','Last Name','Id'],index = False)

# %%
def convert_pepople_cell(cell):
    if cell =="United States":
        return 'U.S'
    return cell 
conv = df_1.applymap(convert_pepople_cell)
conv
# Out:
# C:\Users\kamal\AppData\Local\Temp\ipykernel_17028\652491753.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   conv = df_1.applymap(convert_pepople_cell)
#       0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0     1      Dulce       Abril  Female            U.S   32  15/10/2017  1562
# 1     2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3     4   Kathleen      Hanner  Female            U.S   25  15/10/2017  3549
# 4     5    Nereida     Magwood  Female            U.S   58  16/08/2016  2468
# ..  ...        ...         ...     ...            ...  ...         ...   ...
# 95   96       Roma  Lafollette  Female            U.S   34  15/10/2017  2654
# 96   97     Felisa        Cail  Female            U.S   28  16/08/2016  6525
# 97   98   Demetria       Abbey  Female            U.S   32  21/05/2015  3265
# ...

# %%
df_1
# Out:
#       0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0     1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1     2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3     4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4     5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# ..  ...        ...         ...     ...            ...  ...         ...   ...
# 95   96       Roma  Lafollette  Female  United States   34  15/10/2017  2654
# 96   97     Felisa        Cail  Female  United States   28  16/08/2016  6525
# 97   98   Demetria       Abbey  Female  United States   32  21/05/2015  3265
# 98   99     Jeromy        Danz    Male  United States   39  15/10/2017  3265
# 99  100   Rasheeda      Alkire  Female  United States   29  16/08/2016  6125
#
# [100 rows x 8 columns]

# %%
df.to_excel('NewWExcel.xlsx')

# %%
data1 = pd.DataFrame({
    'tickers' : ['Googl','WMT','MSFT'],
    'price' : [324,434,3434],
    'pe' : [23,23,232],
    'eps' : [32,323,232]
})
data2 = pd.DataFrame({
    'day' : ['1/1/2014','2/2/2018','3/3/2019'],
    'temperature' : [32,232,32],
    'event': ['rain','sunny','snow']
})

# %%
data1
# Out:
#   tickers  price   pe  eps
# 0   Googl    324   23   32
# 1     WMT    434   23  323
# 2    MSFT   3434  232  232

# %%
data2
# Out:
#         day  temperature  event
# 0  1/1/2014           32   rain
# 1  2/2/2018          232  sunny
# 2  3/3/2019           32   snow

# %%
with pd.ExcelWriter('Merge_dictonary.xlsx') as writer:
    data1.to_excel(writer,sheet_name = "Merge")
    data2.to_excel(writer,sheet_name = "dictonary")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\kamal

# %%
import os
print(os.listdir(os.getcwd()))
# Out:
# ['.anaconda', '.angular-config.json', '.bash_history', '.conda', '.condarc', '.config', '.continuum', '.cookiecutters', '.docker', '.dotnet', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.librarymanager', '.nuget', '.omnisharp', '.rest-client', '.templateengine', '.viminfo', '.vscode', '3D Objects', 'abc', 'anaconda3', 'Ap', 'AppData', 'Application Data', 'Contacts', 'ConvertedUsingPandas.csv', 'Cookies', 'customers-100.csv', 'Desktop', 'Documents', 'Downloads', 'Employee Sample Data.csv', 'Employee Sample Data.xlsx', 'Employee_Sample_Data_Cleaned.csv', 'Employee_Sample_Data_Cleaned.xlsx', 'exampleData.xlsx', 'Favorites', 'IntelGraphicsProfiles', 'Interpolated.csv', 'Learn', 'Links', 'Local Settings', 'Merge_dictonary.xlsx', 'Music', 'My Documents', 'NetHood', 'NewWExcel.xlsx', 'node_modules', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMCo
# ...

# %%
import chardet 

def detect_encoding(file_path):
    with open(file_path,'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

file_path = "Employee Sample Data.csv"
encoding =  detect_encoding(file_path)
print(f"Detected encoding{encoding}")
try : 
    df_3 = pd.read_csv(file_path,encoding = encoding)
    print("CSV file read successfully")
except UnicodeDecodeError as e:
    print(f"Error reading the CSV file{e}")

df_filled = df_3.fillna("n.a.")
print("DAta after replacing missing value with 'n.a.':")
print(df_filled)

df_filled.to_csv("Employee_Sample_Data_Cleaned.csv", index=False)
# Out:
# Detected encodingISO-8859-1
# CSV file read successfully
# DAta after replacing missing value with 'n.a.':
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
# ...

# %% [markdown]
# #### file_path1 = "Employee Sample Data.xlsx"
# try:
#     df_4 = pd.read_excel(file_path1)
#     print("Excel file read successfully")
# except UnicodeDecodeError as e:
#     print(f"Error reading the Excel file: {e}")
#
# df_filled1 = df_4.fillna("n.a.")
# print("Data after replacing missing values with 'n.a.':")
# print(df_filled1)
# df_filled1.to_excel("Employee_Sample_Data_Cleaned.xlsx", index=False)

# %%
df_5 = pd.read_csv("Employee_Sample_Data_Cleaned.csv")
df_5
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55    4/8/2016     $141,604
# ...

# %%
type(df_5['Hire Date'][0])
# Out:
# str

# %%
type(df_5.City[0])
# Out:
# str

# %%
df_5['Hire Date'] = pd.to_datetime(df_5['Hire Date'])
df_5
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08     $141,604
# ...

# %%
type(df_5['Hire Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df =  df_5.fillna(0)

# %%
new_df.head(5)
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08     $141,604
# 1           Manufacturing    Male      Asian   59 1997-11-29      $99,975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26     $163,099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27      $84,913
# 4           Manufacturing    Male      Asian   55 1995-11-20      $95,409
#
#   Bonus %        Country       City   Exit Date
# 0     15%  United States    Seattle  10/16/2021
# ...

# %%
type(df_5['Annual Salary'][5])
# Out:
# str

# %%
type(df_5['Annual Salary'][17])
# Out:
# str

# %%
import numpy as np
df_5.replace("n.a.",np.nan,inplace = True)
new_df_5 = df_5.fillna({
    'Full Name' : "No Name",
    'Job Title' : "No Job Title",
    'Department' : "No Department",
    'Business Unit' : "No Business Unit",
    'Gender' : "No Gender",
    'Ethnicity' : "No Ethinicity",
    'Age' : 0,
    'Hire Date' : pd.Timestamp('0001-01-01'),
    'Annual Salary' : 0,
    'Bonus %' : 0,
    'Country' : "Not Specified",
    'City' : 'No City',
    'Exit Date' : "00/00/0000"
})
new_df_5
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender      Ethnicity  Age  Hire Date  \
# 0    Research & Development  Female          Black   55 2016-04-08
# ...

# %%
type(df_5['Annual Salary'][19])
# Out:
# str

# %%
type(df_5['Annual Salary'][17])
# Out:
# float

# %%
type(df_5['Exit Date'][0])
# Out:
# str

# %%
df_5['Annual Salary'] = df_5['Annual Salary'].astype(str)

# %%
type(df_5['Annual Salary'][5])
# Out:
# str

# %%
type(df_5['Annual Salary'][17])
# Out:
# str

# %%
# Replace 'n.a.' strings with NaN values
df_5['Annual Salary'] = df_5['Annual Salary'].replace('n.a.', np.nan)

# Remove all non-digit characters from 'Annual Salary' column
df_5['Annual Salary'] = df_5['Annual Salary'].str.replace(r'\D', '', regex=True)

# Replace empty strings with NaN values
df_5['Annual Salary'] = df_5['Annual Salary'].replace('', np.nan)

# Convert 'Annual Salary' column to float
df_5['Annual Salary'] = df_5['Annual Salary'].astype(float)

# %%
df_5['Annual Salary'][17]
# Out:
# nan

# %%
new_df_5_1 = new_df_5 .fillna(method = "ffill")
new_df_5_1
# Out:
# C:\Users\kamal\AppData\Local\Temp\ipykernel_17028\3625634442.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df_5_1 = new_df_5 .fillna(method = "ffill")
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# ...

# %%
New_interpolate =df_5.interpolate()
New_interpolate
# Out:
# C:\Users\kamal\AppData\Local\Temp\ipykernel_17028\2204274293.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   New_interpolate =df_5.interpolate()
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# ...

# %%
type(New_interpolate['Annual Salary'][17])
# Out:
# numpy.float64

# %%
New_interpolate['Annual Salary'][17]
# Out:
# 181170.0

# %%
New_interpolate.to_csv("Corrected.csv",index = False)
