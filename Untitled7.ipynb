# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv("Boom 1000 Index_D1.CSV",parse_dates = ["date"],index_col = "date")
df
# Out:
#              hour     open      high      low    close  tick_volume
# date
# 2019-04-17  00:00  9897.84   9936.07  9838.62  9922.37     10369207
# 2019-04-18  00:00  9922.36  10022.30  9885.67  9992.95     17552580
# 2019-04-19  00:00  9992.94   9992.94  9749.33  9770.52     14502990
# 2019-04-20  00:00  9770.52   9952.90  9769.89  9914.83     18003090
# 2019-04-21  00:00  9914.82   9971.02  9810.98  9880.83     16582400
# ...           ...      ...       ...      ...      ...          ...
# 2021-01-06  00:00  9807.22   9854.33  9704.95  9738.30        83973
# 2021-01-07  00:00  9738.28   9815.43  9710.58  9774.13        83925
# 2021-01-08  00:00  9774.12   9956.63  9768.01  9864.10        83951
# 2021-01-09  00:00  9864.08   9986.56  9797.84  9797.84        84020
# 2021-01-10  00:00  9797.83   9871.52  9709.84  9829.67        83479
#
# [635 rows x 6 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2019-04-17', '2019-04-18', '2019-04-19', '2019-04-20',
#                '2019-04-21', '2019-04-22', '2019-04-23', '2019-04-24',
#                '2019-04-25', '2019-04-26',
#                ...
#                '2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10'],
#               dtype='datetime64[ns]', name='date', length=635, freq=None)

# %%
df["tick_volume"].resample('Y').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
df["tick_volume"].resample('Y').mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='date'>

# %%
# %matplotlib inline
df.close.plot()
# Out:
# <Axes: xlabel='date'>

# %%
 df.asfreq('D',method = 'pad')
# Out:
#              hour     open      high      low    close  tick_volume
# date
# 2019-04-17  00:00  9897.84   9936.07  9838.62  9922.37     10369207
# 2019-04-18  00:00  9922.36  10022.30  9885.67  9992.95     17552580
# 2019-04-19  00:00  9992.94   9992.94  9749.33  9770.52     14502990
# 2019-04-20  00:00  9770.52   9952.90  9769.89  9914.83     18003090
# 2019-04-21  00:00  9914.82   9971.02  9810.98  9880.83     16582400
# ...           ...      ...       ...      ...      ...          ...
# 2021-01-06  00:00  9807.22   9854.33  9704.95  9738.30        83973
# 2021-01-07  00:00  9738.28   9815.43  9710.58  9774.13        83925
# 2021-01-08  00:00  9774.12   9956.63  9768.01  9864.10        83951
# 2021-01-09  00:00  9864.08   9986.56  9797.84  9797.84        84020
# 2021-01-10  00:00  9797.83   9871.52  9709.84  9829.67        83479
#
# [635 rows x 6 columns]

# %%
rng = pd.date_range(start = "1/1/2017",periods = 72,freq= 'B')
rng
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05',
#                '2017-01-06', '2017-01-09', '2017-01-10', '2017-01-11',
#                '2017-01-12', '2017-01-13', '2017-01-16', '2017-01-17',
#                '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23',
#                '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27',
#                '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02',
#                '2017-02-03', '2017-02-06', '2017-02-07', '2017-02-08',
#                '2017-02-09', '2017-02-10', '2017-02-13', '2017-02-14',
#                '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-20',
#                '2017-02-21', '2017-02-22', '2017-02-23', '2017-02-24',
#                '2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10', '2017-03-13', '2017-03-14',
# ...

# %%
import numpy as np 
np.random.randint(1,10,len(rng))
# Out:
# array([9, 8, 3, 4, 1, 6, 6, 2, 2, 3, 9, 1, 4, 6, 7, 3, 2, 1, 8, 5, 8, 7,
#        7, 1, 7, 8, 9, 6, 3, 1, 5, 2, 6, 2, 3, 4, 7, 3, 3, 5, 3, 4, 3, 7,
#        2, 6, 6, 8, 3, 9, 6, 4, 1, 1, 5, 9, 7, 9, 4, 8, 6, 4, 7, 4, 7, 7,
#        4, 8, 9, 5, 9, 8])

# %%
df_1 = pd.Series(np.random.randint(1,10,len(rng)),index = rng)
df_1
# Out:
# 2017-01-02    9
# 2017-01-03    7
# 2017-01-04    7
# 2017-01-05    1
# 2017-01-06    9
#              ..
# 2017-04-05    4
# 2017-04-06    6
# 2017-04-07    4
# 2017-04-10    1
# 2017-04-11    2
# Freq: B, Length: 72, dtype: int32

# %%
dates = ['2017-01-03 2:30 PM','jan 5,2017 14:30:00','01/05/2017','2017.01.05','ABC']
pd.to_datetime(dates,errors = 'ignore')
# Out:
# C:\Users\kamal\AppData\Local\Temp\ipykernel_14280\1466183709.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(dates,errors = 'ignore')
# Index(['2017-01-03 2:30 PM', 'jan 5,2017 14:30:00', '01/05/2017', '2017.01.05',
#        'ABC'],
#       dtype='object')

# %%
dates1 = ['2017-01-03 2:30 PM','jan 5,2017 14:30:00','01/05/2017','2017.01.05','ABC']
pd.to_datetime(dates,errors = 'coerce')
# Out:
# C:\Users\kamal\AppData\Local\Temp\ipykernel_14280\2965495751.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(dates,errors = 'coerce')
# DatetimeIndex(['2017-01-03 14:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %%
epoc_time = 1501356749
dt  =  pd.to_datetime([epoc_time],unit = 's')
dt
# Out:
# DatetimeIndex(['2017-07-29 19:32:29'], dtype='datetime64[ns]', freq=None)

# %%
dt.view('int64')
# Out:
# array([1501356749000000000], dtype=int64)

# %%
y = pd.Period('2016')
y
# Out:
# Period('2016', 'A-DEC')

# %%
y.start_time
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2016-12-31 23:59:59.999999999')

# %%
m = pd.Period('2015-12',freq = 'M')
m
# Out:
# Period('2015-12', 'M')

# %%
m + 1
# Out:
# Period('2016-01', 'M')

# %%
d = pd.Period('2017-02-28',freq='D')
d
# Out:
# Period('2017-02-28', 'D')

# %%
d+1
# Out:
# Period('2017-03-01', 'D')

# %%
d.asfreq("M",how = "start")
# Out:
# Period('2017-02', 'M')

# %%
q = pd.Period('2017Q1',freq = "Q-JAN")
q
# Out:
# Period('2017Q1', 'Q-JAN')

# %%
q2 = pd.Period('2018Q2',freq = "Q-JAN")
q2
# Out:
# Period('2018Q2', 'Q-JAN')

# %%
q2-q
# Out:
# <5 * QuarterEnds: startingMonth=1>

# %%
idx = pd.period_range('2011',periods = 10,freq = 'Q-JAN')
idx
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]')

# %%
ps = pd.Series(np.random.randn(len(idx)),idx)
ps
# Out:
# 2011Q4    0.639435
# 2012Q1    0.478763
# 2012Q2    0.563961
# 2012Q3    0.254044
# 2012Q4    0.998073
# 2013Q1    0.259698
# 2013Q2   -2.546242
# 2013Q3    0.891476
# 2013Q4   -0.524780
# 2014Q1   -0.659578
# Freq: Q-JAN, dtype: float64

# %%
ps.index
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]')

# %%
ps['2011']
# Out:
# 2011Q4    0.639435
# 2012Q1    0.478763
# 2012Q2    0.563961
# 2012Q3    0.254044
# 2012Q4    0.998073
# Freq: Q-JAN, dtype: float64

# %%
ps['2011':'2013']
# Out:
# 2011Q4    0.639435
# 2012Q1    0.478763
# 2012Q2    0.563961
# 2012Q3    0.254044
# 2012Q4    0.998073
# 2013Q1    0.259698
# 2013Q2   -2.546242
# 2013Q3    0.891476
# 2013Q4   -0.524780
# 2014Q1   -0.659578
# Freq: Q-JAN, dtype: float64

# %%
ps.index
# Out:
# PeriodIndex(['2011Q4', '2012Q1', '2012Q2', '2012Q3', '2012Q4', '2013Q1',
#              '2013Q2', '2013Q3', '2013Q4', '2014Q1'],
#             dtype='period[Q-JAN]')

# %%
ps_datetime = ps.to_timestamp()
ps_datetime
# Out:
# 2010-11-01    0.639435
# 2011-02-01    0.478763
# 2011-05-01    0.563961
# 2011-08-01    0.254044
# 2011-11-01    0.998073
# 2012-02-01    0.259698
# 2012-05-01   -2.546242
# 2012-08-01    0.891476
# 2012-11-01   -0.524780
# 2013-02-01   -0.659578
# Freq: QS-NOV, dtype: float64

# %%
df12 = df.tz_localize(tz = 'US/Eastern')
df12
# Out:
#                             hour     open      high      low    close  \
# date
# 2019-04-17 00:00:00-04:00  00:00  9897.84   9936.07  9838.62  9922.37
# 2019-04-18 00:00:00-04:00  00:00  9922.36  10022.30  9885.67  9992.95
# 2019-04-19 00:00:00-04:00  00:00  9992.94   9992.94  9749.33  9770.52
# 2019-04-20 00:00:00-04:00  00:00  9770.52   9952.90  9769.89  9914.83
# 2019-04-21 00:00:00-04:00  00:00  9914.82   9971.02  9810.98  9880.83
# ...                          ...      ...       ...      ...      ...
# 2021-01-06 00:00:00-05:00  00:00  9807.22   9854.33  9704.95  9738.30
# 2021-01-07 00:00:00-05:00  00:00  9738.28   9815.43  9710.58  9774.13
# 2021-01-08 00:00:00-05:00  00:00  9774.12   9956.63  9768.01  9864.10
# 2021-01-09 00:00:00-05:00  00:00  9864.08   9986.56  9797.84  9797.84
# 2021-01-10 00:00:00-05:00  00:00  9797.83   9871.52  9709.84  9829.67
#
#                            tick_volume
# date
# 2019-04-17 00:00:00-04:00     10369207
# ...

# %%
df12 = df12.tz_convert(tz = 'Europe/Berlin')
df12
# Out:
#                             hour     open      high      low    close  \
# date
# 2019-04-17 06:00:00+02:00  00:00  9897.84   9936.07  9838.62  9922.37
# 2019-04-18 06:00:00+02:00  00:00  9922.36  10022.30  9885.67  9992.95
# 2019-04-19 06:00:00+02:00  00:00  9992.94   9992.94  9749.33  9770.52
# 2019-04-20 06:00:00+02:00  00:00  9770.52   9952.90  9769.89  9914.83
# 2019-04-21 06:00:00+02:00  00:00  9914.82   9971.02  9810.98  9880.83
# ...                          ...      ...       ...      ...      ...
# 2021-01-06 06:00:00+01:00  00:00  9807.22   9854.33  9704.95  9738.30
# 2021-01-07 06:00:00+01:00  00:00  9738.28   9815.43  9710.58  9774.13
# 2021-01-08 06:00:00+01:00  00:00  9774.12   9956.63  9768.01  9864.10
# 2021-01-09 06:00:00+01:00  00:00  9864.08   9986.56  9797.84  9797.84
# 2021-01-10 06:00:00+01:00  00:00  9797.83   9871.52  9709.84  9829.67
#
#                            tick_volume
# date
# 2019-04-17 06:00:00+02:00     10369207
# ...

# %%
from pytz import all_timezones
all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
df12 = df12.tz_convert(tz = 'Europe/Helsinki')
df12
# Out:
#                             hour     open      high      low    close  \
# date
# 2019-04-17 07:00:00+03:00  00:00  9897.84   9936.07  9838.62  9922.37
# 2019-04-18 07:00:00+03:00  00:00  9922.36  10022.30  9885.67  9992.95
# 2019-04-19 07:00:00+03:00  00:00  9992.94   9992.94  9749.33  9770.52
# 2019-04-20 07:00:00+03:00  00:00  9770.52   9952.90  9769.89  9914.83
# 2019-04-21 07:00:00+03:00  00:00  9914.82   9971.02  9810.98  9880.83
# ...                          ...      ...       ...      ...      ...
# 2021-01-06 07:00:00+02:00  00:00  9807.22   9854.33  9704.95  9738.30
# 2021-01-07 07:00:00+02:00  00:00  9738.28   9815.43  9710.58  9774.13
# 2021-01-08 07:00:00+02:00  00:00  9774.12   9956.63  9768.01  9864.10
# 2021-01-09 07:00:00+02:00  00:00  9864.08   9986.56  9797.84  9797.84
# 2021-01-10 07:00:00+02:00  00:00  9797.83   9871.52  9709.84  9829.67
#
#                            tick_volume
# date
# 2019-04-17 07:00:00+03:00     10369207
# ...

# %%
ps_datetime.shift(1)
# Out:
# 2010-11-01         NaN
# 2011-02-01    0.639435
# 2011-05-01    0.478763
# 2011-08-01    0.563961
# 2011-11-01    0.254044
# 2012-02-01    0.998073
# 2012-05-01    0.259698
# 2012-08-01   -2.546242
# 2012-11-01    0.891476
# 2013-02-01   -0.524780
# Freq: QS-NOV, dtype: float64

# %%
df123 = ps_datetime.reset_index()

# Rename the columns to "Date" and "Price"
df123.columns = ['Date', 'Price']

# %%
df123
# Out:
#         Date     Price
# 0 2010-11-01  0.639435
# 1 2011-02-01  0.478763
# 2 2011-05-01  0.563961
# 3 2011-08-01  0.254044
# 4 2011-11-01  0.998073
# 5 2012-02-01  0.259698
# 6 2012-05-01 -2.546242
# 7 2012-08-01  0.891476
# 8 2012-11-01 -0.524780
# 9 2013-02-01 -0.659578

# %%
df123['Previous Day Price'] = df123['Price'].shift(1)
df123
# Out:
#         Date     Price  Previous Day Price
# 0 2010-11-01  0.639435                 NaN
# 1 2011-02-01  0.478763            0.639435
# 2 2011-05-01  0.563961            0.478763
# 3 2011-08-01  0.254044            0.563961
# 4 2011-11-01  0.998073            0.254044
# 5 2012-02-01  0.259698            0.998073
# 6 2012-05-01 -2.546242            0.259698
# 7 2012-08-01  0.891476           -2.546242
# 8 2012-11-01 -0.524780            0.891476
# 9 2013-02-01 -0.659578           -0.524780

# %%
df123['Change Price'] = df123['Price'] - df123['Previous Day Price']
df123
# Out:
#         Date     Price  Previous Day Price  Change Price
# 0 2010-11-01  0.639435                 NaN           NaN
# 1 2011-02-01  0.478763            0.639435     -0.160673
# 2 2011-05-01  0.563961            0.478763      0.085199
# 3 2011-08-01  0.254044            0.563961     -0.309917
# 4 2011-11-01  0.998073            0.254044      0.744029
# 5 2012-02-01  0.259698            0.998073     -0.738375
# 6 2012-05-01 -2.546242            0.259698     -2.805940
# 7 2012-08-01  0.891476           -2.546242      3.437718
# 8 2012-11-01 -0.524780            0.891476     -1.416256
# 9 2013-02-01 -0.659578           -0.524780     -0.134798

# %%
df123['5 day % return'] = (df123['Price'] -df123['Price'].shift(5))*100/df123['Price'].shift(5)
df123
# Out:
#         Date     Price  Previous Day Price  Change Price  5 day % return
# 0 2010-11-01  0.639435                 NaN           NaN             NaN
# 1 2011-02-01  0.478763            0.639435     -0.160673             NaN
# 2 2011-05-01  0.563961            0.478763      0.085199             NaN
# 3 2011-08-01  0.254044            0.563961     -0.309917             NaN
# 4 2011-11-01  0.998073            0.254044      0.744029             NaN
# 5 2012-02-01  0.259698            0.998073     -0.738375      -59.386324
# 6 2012-05-01 -2.546242            0.259698     -2.805940     -631.837877
# 7 2012-08-01  0.891476           -2.546242      3.437718       58.073902
# 8 2012-11-01 -0.524780            0.891476     -1.416256     -306.570121
# 9 2013-02-01 -0.659578           -0.524780     -0.134798     -166.085084
